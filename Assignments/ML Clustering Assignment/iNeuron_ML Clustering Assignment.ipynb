# %%
from sklearn.cluster import KMeans
import numpy as np
from sklearn import cluster, datasets
from scipy import misc
import matplotlib.pyplot as plt
% matplotlib inline

# %%
face = misc.face(gray = True)

# %%
face.shape
# Out:
# (768, 1024)

# %%
plt.imsave('original_racoon.png', face)

# %%
plt.figure(figsize=(15, 8))
plt.imshow(face, cmap=plt.cm.gray)
plt.show()

# %%
n_cluster = 5

# %%
rows = face.shape[0]
cols = face.shape[1]

# %%
img = face.reshape(rows*cols,1)
img.shape
# Out:
# (786432, 1)

# %%
kmeans = KMeans(n_clusters = n_cluster, n_init= 10)
kmeans.fit(img)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clusters = np.asarray(kmeans.cluster_centers_) 
labels = np.asarray(kmeans.labels_)

# %%
labels = labels.reshape(rows, cols)

# %%
labels
# Out:
# array([[0, 0, 4, ..., 0, 0, 4],
#        [3, 0, 0, ..., 0, 4, 4],
#        [3, 3, 0, ..., 0, 4, 4],
#        ...,
#        [0, 0, 0, ..., 4, 4, 4],
#        [0, 0, 0, ..., 4, 4, 4],
#        [0, 0, 0, ..., 4, 4, 4]])

# %%
plt.imsave('compressed_racoon.png',labels)

image = plt.imread('compressed_racoon.png')
plt.figure(figsize=(10, 3.6))
plt.imshow(image)
plt.show()

# %% [markdown]
# ### Original Image Size = 1.23 Mb
# ### Compressed Image size = 171 Kb
